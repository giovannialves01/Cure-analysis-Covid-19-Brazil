# %%
import pandas as pd
low_memory=False #pq o arquivo é muito grande e memo assim meu pc ainda n abre as vezes hahaha
# %matplotlib notebook

# %%
seila = pd.read_csv(r'C:\Users\andrey\Documents\GitHub\Cure-analysis-Covid-19-Brazil\HIST_PAINEL_COVIDBR_03jul2020.csv', delimiter=';')
#o utf-8 é melhos nesse caso pois a codificaçã

# %%
for k in range(17): print (k, seila.columns[k]) #pega todas as colunas do doido
# Out:
# 0 regiao
# 1 estado
# 2 municipio
# 3 coduf
# 4 codmun
# 5 codRegiaoSaude
# 6 nomeRegiaoSaude
# 7 data
# 8 semanaEpi
# 9 populacaoTCU2019
# 10 casosAcumulado
# 11 casosNovos
# 12 obitosAcumulado
# 13 obitosNovos
# 14 Recuperadosnovos
# 15 emAcompanhamentoNovos
# 16 interior/metropolitana

# %%
seila
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0             Brasil    NaN       NaN     76       NaN             NaN
# 1             Brasil    NaN       NaN     76       NaN             NaN
# 2             Brasil    NaN       NaN     76       NaN             NaN
# 3             Brasil    NaN       NaN     76       NaN             NaN
# 4             Brasil    NaN       NaN     76       NaN             NaN
# ...              ...    ...       ...    ...       ...             ...
# 535859  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 535860  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 535861  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 535862  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 535863  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#          nomeRegiaoSaude        data  semanaEpi populacaoTCU2019  \
# ...

# %%
seila.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 535864 entries, 0 to 535863
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   regiao                  535864 non-null  object
#  1   estado                  535734 non-null  object
#  2   municipio               530145 non-null  object
#  3   coduf                   535864 non-null  int64
#  4   codmun                  532224 non-null  float64
#  5   codRegiaoSaude          530145 non-null  float64
#  6   nomeRegiaoSaude         530145 non-null  object
#  7   data                    535864 non-null  object
#  8   semanaEpi               535864 non-null  int64
#  9   populacaoTCU2019        533785 non-null  object
#  10  casosAcumulado          535864 non-null  int64
#  11  casosNovos              535864 non-null  int64
#  12  obitosAcumulado         535864 non-null  int64
#  13  obitosNovos             535864 non-null  int64
# ...

# %%
seila.shape
# Out:
# (535864, 17)

# %%
seila.describe()
# Out:
#                coduf         codmun  codRegiaoSaude      semanaEpi  \
# count  535864.000000  532224.000000   530145.000000  535864.000000
# mean       32.080246  322476.410528    32123.513725      20.267792
# std         9.780099   97484.738466     9729.462448       4.106503
# min        11.000000  110000.000000    11001.000000       9.000000
# 25%        25.000000  250977.500000    25008.000000      17.000000
# 50%        31.000000  314125.000000    31051.000000      20.000000
# 75%        41.000000  411282.500000    41011.000000      24.000000
# max        76.000000  530010.000000    53001.000000      27.000000
#
#        casosAcumulado     casosNovos  obitosAcumulado    obitosNovos  \
# count    5.358640e+05  535864.000000    535864.000000  535864.000000
# mean     2.331577e+02       8.616446        11.835768       0.353676
# std      8.796845e+03     297.752383       430.462416      11.338205
# min      0.000000e+00   -1812.000000         0.000000     -36.000000
# ...

# %%
seila.info
# Out:
# <bound method DataFrame.info of               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0             Brasil    NaN       NaN     76       NaN             NaN
# 1             Brasil    NaN       NaN     76       NaN             NaN
# 2             Brasil    NaN       NaN     76       NaN             NaN
# 3             Brasil    NaN       NaN     76       NaN             NaN
# 4             Brasil    NaN       NaN     76       NaN             NaN
# ...              ...    ...       ...    ...       ...             ...
# 535859  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 535860  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 535861  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 535862  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 535863  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#          nomeRegiaoSaude        data  semanaEpi populacaoTCU2019  \
# ...

# %%
seila.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 535864 entries, 0 to 535863
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   regiao                  535864 non-null  object
#  1   estado                  535734 non-null  object
#  2   municipio               530145 non-null  object
#  3   coduf                   535864 non-null  int64
#  4   codmun                  532224 non-null  float64
#  5   codRegiaoSaude          530145 non-null  float64
#  6   nomeRegiaoSaude         530145 non-null  object
#  7   data                    535864 non-null  object
#  8   semanaEpi               535864 non-null  int64
#  9   populacaoTCU2019        533785 non-null  object
#  10  casosAcumulado          535864 non-null  int64
#  11  casosNovos              535864 non-null  int64
#  12  obitosAcumulado         535864 non-null  int64
#  13  obitosNovos             535864 non-null  int64
# ...

# %%
seila.groupby('casosAcumulado').size().sort_values().tail(3).plot(kind='barh')

# %%
seila.query('casosAcumulado')['data'].value_counts().tail(3).plot(kind='barh')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-ffb014575fe5> in <module>
# ----> 1 seila.query('casosAcumulado')['data'].value_counts().tail(3).plot(kind='barh')
#
# c:\users\andrey\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py in query(self, expr, inplace, **kwargs)
#    3232
#    3233         try:
# -> 3234             new_data = self.loc[res]
#    3235         except ValueError:
#    3236             # when res is multi-dimensional loc raises, but this is sometimes a
#
# c:\users\andrey\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ...

# %%
seila.groupby('data').size().sort_values().tail(3).plot(kind='barh')

# %%
dates = pd.date_range('25/02/2020', periods=129)

# %%
df = pd.DataFrame(index=dates, columns=['casosAcumulado', 'casosNovos', 'obitosAcumulado', 'obitosNovos'])

# %%
seila.query('regiao == "Brasil" ')['casosNovos'].tail(5).plot(kind='barh')

# %%
seila.query('regiao == "Brasil" ')['Recuperadosnovos'].tail(5).plot(kind='barh')
